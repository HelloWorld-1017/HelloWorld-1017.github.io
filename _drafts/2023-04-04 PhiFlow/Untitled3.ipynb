# %%
import phi
phi.verify()
# Out:
# PhiFlow 2.3.2 at G:\anaconda3\envs\PDEenv\lib\site-packages\phi
# Web interface: OK (dash 2.7.0)
# PyTorch: Installed (2.0.0 at G:\anaconda3\envs\PDEenv\lib\site-packages\torch), 1 GPUs available.
# Jax: Not installed.
# TensorFlow: Not installed.

# %%
# from phi.flow import *
from phi.torch.flow import *

# %%
math.zeros()
# Out:
# 0.0

# %%
math.random_normal()
# Out:
# -0.176543

# %%
a = math.random_normal(batch(dim1=10))
b = math.random_normal(batch(dim2=10))
a,b
# Out:
# ((dim1ᵇ=10) 0.281 ± 0.959 (-2e+00...1e+00),
#  (dim2ᵇ=10) 0.647 ± 0.765 (-6e-01...2e+00))

# %%
c = a+b

# %%
c.dim1[:5].dim2[-1]
# Out:
# (0.432, 0.710, 0.861, 0.219, 0.314) along dim1ᵇ

# %%
math.tensor(numpy.random.random(10),batch(dim2=10))
# Out:
# (dim2ᵇ=10) 0.408 ± 0.274 (8e-02...9e-01)

# %%
grid = math.ones(spatial(x=4, y=3, z=3))
grid
# Out:
# (xˢ=4, yˢ=3, zˢ=3) const 1.0

# %%
math.spatial_gradient(grid)
# Out:
# (xˢ=4, yˢ=3, zˢ=3, gradientᶜ=3) const 0.0

# %%
instance(points=100)
# Out:
# (pointsⁱ=100)

# %%
channel(color=3)
# Out:
# (colorᶜ=3)

# %%
channel(vector=3)
# Out:
# (vectorᶜ=3)

# %%
a.native()
# Out:
# tensor([ 1.0115,  1.2890,  1.4402,  0.7984,  0.8930, -0.3618, -0.5516, -0.3533,
#          0.4005, -1.7521], device='cuda:0')

# %%
type(a.native())
# Out:
# torch.Tensor

# %%
# https://tum-pbs.github.io/PhiFlow/phi/math/
